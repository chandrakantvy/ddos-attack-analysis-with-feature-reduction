# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Imports
import pandas as pd
import numpy as np
import random

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, confusion_matrix, classification_report

from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB

# %%
# Defining some Globals
RANDOM_STATE = 42
THRESHOLD = 0.0001
NUM_FOLDS = 3
MIN_NUM_FEATURES = 40
CATEGORICAL_FEATURE_COUNT=2
TEST_SPLIT_PROPORTION=0.6
AGGRESSIVE=False

# %%
# Getting the Dataset
import pandas as pd
feat_info = pd.read_csv("/content/drive/My Drive/B Tech Project/DataSet 2018/Feat_info.csv", index_col="Feature Name", squeeze=True)
df = pd.read_csv("/content/drive/My Drive/B Tech Project/DataSet 2018/DDoS_2018.csv")
# Re-ordering the Columns to that in Feat_info.csv
df = pd.DataFrame(df, columns=feat_info.index)

# %%
# Categorical Columns need to be handled as well
# They include: Protocol, Dst Port and Label

df.loc[df["Protocol"] == 17, "Protocol"] = "UDP"
df.loc[df["Protocol"] == 6, "Protocol"] = "TCP"
df.loc[df["Protocol"] == 0, "Protocol"] = "HOPOPT"
protocol = pd.get_dummies(df["Protocol"], prefix="protocol")
df = pd.concat([df, protocol], axis=1)
df.drop("Protocol", axis=1, inplace=True)

df["protocol_HOPOPT"].astype("category")
df["protocol_UDP"].astype("category")
df["protocol_TCP"].astype("category")

# For Dst Port it is benign for all non-80 values
# So we can make the dataset more balanced by dropping
# the column itself so that the model is not biased on
# the basis of the port
df.drop("Dst Port", axis=1, inplace=True)

# Labels are: DDOS attack-HOIC (233961), Benign (126289), DDOS attack-LOIC-UDP (1211)
mapping = {"Benign": 0, "DDOS attack-HOIC": 1, "DDOS attack-LOIC-UDP": 2}
df["Label"] = df["Label"].apply(lambda label: mapping[label])

# %%
# Removing Timestamp
df.drop(columns=["Timestamp"], inplace=True)

# %%
# Stratification of DataSet
# Feature reduction will be done on the training dataset only
X_train, X_test, y_train, y_test = train_test_split(df.drop(columns=["Label"]), df["Label"], test_size=TEST_SPLIT_PROPORTION, stratify=df["Label"], random_state=RANDOM_STATE)

# df -> Training Dataset
# test -> Testing Dataset
df = pd.concat([X_train, y_train], axis=1)
df.reset_index(drop=True, inplace=True)

test = pd.concat([X_test, y_test], axis=1)
test.reset_index(drop=True, inplace=True)

# %%
myModel=GaussianNB()
myModel.fit(df.drop(columns=["Label"]), df["Label"])
pred=myModel.predict(test.drop(columns=["Label"]))
print(classification_report(test["Label"], pred, output_dict=True)["macro avg"])
# Out:
# {'precision': 0.9999644120087142, 'recall': 0.9999502403705236, 'f1-score': 0.999957325271238, 'support': 309825}

# %%
myModel=RandomForestClassifier()
myModel.fit(df.drop(columns=["Label"]), df["Label"])
pred=myModel.predict(test.drop(columns=["Label"]))
print(classification_report(test["Label"], pred, output_dict=True)["macro avg"])
# Out:
# {'precision': 0.9999966756590091, 'recall': 0.9999938413026875, 'f1-score': 0.9999952584441124, 'support': 309825}

# %%
myModel=LinearSVC(dual=False)
myModel.fit(df.drop(columns=["Label"]), df["Label"])
pred=myModel.predict(test.drop(columns=["Label"]))
print(classification_report(test["Label"], pred, output_dict=True)["macro avg"])
# Out:
# {'precision': 0.9996392255420911, 'recall': 0.9996080446019743, 'f1-score': 0.9996236306268526, 'support': 309825}

# %%
# Removing columns with constant values
for column_name in df.columns:
    if df[column_name].nunique() == 1:
        df.drop(column_name, axis=1, inplace=True)

# %%
# Standard-scaling the continuous features
categorical = []
continuous = []
count = pd.DataFrame(dtype=np.int64, columns=["Number of Values"])
for column_name in df.columns:
    if column_name != "Label":
        count.loc[column_name] = df[column_name].nunique()
        if df[column_name].nunique() != CATEGORICAL_FEATURE_COUNT:
            continuous.append(column_name)

# Standard Scaling all the Continuous Values
scaler = StandardScaler()
scaler.fit(df[continuous])
df[continuous] = scaler.transform(df[continuous])

# %%
# Ranking the features for heuristic search implementation
corrData = df.corr().abs().loc["Label"].sort_values().drop("Label")
ranked_features = list(corrData.index)

# %%
# myModel = RandomForestClassifier()
# myModel.fit(df.drop(columns=["Label"]), df["Label"])
# predictions=myModel.predict(pd.DataFrame(test, columns=df.columns).drop(columns=["Label"]))
# print(f1_score(test["Label"], predictions, average="macro"))

# %%
def evaluateModel(test, model_of_choice, cross_validation_count=5):
    print(f"Testing for {len(test.columns)} Features")
    score = 0
    for i in range(cross_validation_count):
        # print(f"Iteration {i+1} of cross-validation")

        X_train_fold = pd.concat([test.drop(columns=["Label"]).iloc[:i * len(
            test) // cross_validation_count, :], test.drop(columns=["Label"]).iloc[(i+1) * len(test) // cross_validation_count: , :]])
        y_train_fold = pd.concat([test["Label"][:i * len(test) // cross_validation_count], test["Label"].iloc[(i+1) * len(test) // cross_validation_count:]])

        X_test_fold = test.drop(columns=["Label"]).iloc[i * len(test) // cross_validation_count: (i + 1) * len(test) // cross_validation_count, :]
        y_test_fold = test["Label"].iloc[i * len(test) // cross_validation_count: (i + 1) * len(test) // cross_validation_count]

        myModel = model_of_choice
        myModel.fit(X_train_fold, y_train_fold)
        predictions = myModel.predict(X_test_fold)

        score += f1_score(y_test_fold, predictions, average="macro") / cross_validation_count

    return score

# %%
def modified_backward_wrapper(training, testing, model_of_choice, ranking, min_features, num_folds, threshold, aggressive=False):
    '''
    Helper Function returning the current running score, the best overall score and score against test data
    '''  
    score_data = {}
    final_features = ranking.copy()
    
    final_accuracy = evaluateModel(training, model_of_choice, NUM_FOLDS)
    myModel = model_of_choice
    myModel.fit(pd.DataFrame(training, columns=final_features), training["Label"])
    predictions = myModel.predict(pd.DataFrame(testing, columns=final_features))

    score_data[len(final_features)] = [final_accuracy, final_accuracy, "-", f1_score(testing["Label"], predictions, average="macro")]
    
    while len(final_features) > min_features:
        flag = 1
        print(f"-------------------Checking for {len(final_features) - 1} Features-------------------")
        for index, feature in enumerate(final_features):
            # feature to be removed is: "feature"
            # we will train on the remaining features and testfor f1_score
            print(f"Testing for importance of {feature}")

            score = evaluateModel(pd.DataFrame(training, columns=final_features + ["Label"]).drop(columns=[feature]), model_of_choice, num_folds)
            print(f"{len(final_features) - 1}: {score} & {final_accuracy}")
            if (abs(score - final_accuracy) < threshold and aggressive) or (not aggressive and score >= final_accuracy):
                final_accuracy = max(score, final_accuracy)
                final_features.remove(feature)
                flag = 0

                myModel = model_of_choice
                myModel.fit(pd.DataFrame(training, columns=final_features), training["Label"])
                predictions = myModel.predict(pd.DataFrame(testing, columns=final_features))

                score_data[len(final_features)] = [score, final_accuracy, feature, final_features]
                break

        print(f"{len(final_features)} Features after removal: {final_features}")
        print(f"{score_data[len(final_features)]}")
        if flag:
            break
      
    return score_data, final_features

# %%
scoresNB, final_featuresNB = modified_backward_wrapper(df, test, GaussianNB(), ranked_features, MIN_NUM_FEATURES, NUM_FOLDS, THRESHOLD, AGGRESSIVE)
# Out:
# Testing for 69 Features
# -------------------Checking for 67 Features-------------------
# Testing for importance of Fwd Pkt Len Min
# Testing for 68 Features
# 67: 0.9999537617884362 & 0.9999537617884362
# 67 Features after removal: ['Pkt Len Min', 'Bwd Pkt Len Min', 'SYN Flag Cnt', 'Fwd PSH Flags', 'URG Flag Cnt', 'protocol_HOPOPT', 'Bwd IAT Tot', 'Bwd IAT Std', 'Flow IAT Min', 'Fwd IAT Min', 'Bwd IAT Max', 'Active Std', 'Idle Min', 'Fwd IAT Mean', 'Flow IAT Mean', 'Active Min', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Bwd IAT Mean', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Fwd Header Len', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']
# [0.9999537617884362, 0.9999537617884362, 'Fwd Pkt Len Min', ['Pkt Len Min', 'Bwd Pkt Len Min', 'SYN Flag Cnt', 'Fwd PSH Flags', 'URG Flag Cnt', 'protocol_HOPOPT', 'Bwd IAT Tot', 'Bwd IAT Std', 'Flow IAT Min', 'Fwd IAT Min', 'Bwd IAT Max', 'Active Std', 'Idle Min', 'Fwd IAT Mean', 'Flow IAT Mean', 'Active Min', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Bwd IAT Mean', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Fwd Header Len', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']]
# -------------------Checking for 66 Features-------------------
# Testing for importance of Pkt Len Min
# Testing for 67 Features
# 66: 0.9999537617884362 & 0.9999537617884362
# 66 Features after removal: ['Bwd Pkt Len Min', 'SYN Flag Cnt', 'Fwd PSH Flags', 'URG Flag Cnt', 'protocol_HOPOPT', 'Bwd IAT Tot', 'Bwd IAT Std', 'Flow IAT Min', 'Fwd IAT Min', 'Bwd IAT Max', 'Active Std', 'Idle Min', 'Fwd IAT Mean', 'Flow IAT Mean', 'Active Min', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Bwd IAT Mean', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Fwd Header Len', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']
# [0.9999537617884362, 0.9999537617884362, 'Pkt Len Min', ['Bwd Pkt Len Min', 'SYN Flag Cnt', 'Fwd PSH Flags', 'URG Flag Cnt', 'protocol_HOPOPT', 'Bwd IAT Tot', 'Bwd IAT Std', 'Flow IAT Min', 'Fwd IAT Min', 'Bwd IAT Max', 'Active Std', 'Idle Min', 'Fwd IAT Mean', 'Flow IAT Mean', 'Active Min', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Bwd IAT Mean', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Fwd Header Len', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']]
# -------------------Checking for 65 Features-------------------
# Testing for importance of Bwd Pkt Len Min
# Testing for 66 Features
# 65: 0.9999537617884362 & 0.9999537617884362
# 65 Features after removal: ['SYN Flag Cnt', 'Fwd PSH Flags', 'URG Flag Cnt', 'protocol_HOPOPT', 'Bwd IAT Tot', 'Bwd IAT Std', 'Flow IAT Min', 'Fwd IAT Min', 'Bwd IAT Max', 'Active Std', 'Idle Min', 'Fwd IAT Mean', 'Flow IAT Mean', 'Active Min', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Bwd IAT Mean', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Fwd Header Len', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']
# [0.9999537617884362, 0.9999537617884362, 'Bwd Pkt Len Min', ['SYN Flag Cnt', 'Fwd PSH Flags', 'URG Flag Cnt', 'protocol_HOPOPT', 'Bwd IAT Tot', 'Bwd IAT Std', 'Flow IAT Min', 'Fwd IAT Min', 'Bwd IAT Max', 'Active Std', 'Idle Min', 'Fwd IAT Mean', 'Flow IAT Mean', 'Active Min', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Bwd IAT Mean', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Fwd Header Len', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']]
# -------------------Checking for 64 Features-------------------
# Testing for importance of SYN Flag Cnt
# Testing for 65 Features
# 64: 0.9999537617884362 & 0.9999537617884362
# 64 Features after removal: ['Fwd PSH Flags', 'URG Flag Cnt', 'protocol_HOPOPT', 'Bwd IAT Tot', 'Bwd IAT Std', 'Flow IAT Min', 'Fwd IAT Min', 'Bwd IAT Max', 'Active Std', 'Idle Min', 'Fwd IAT Mean', 'Flow IAT Mean', 'Active Min', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Bwd IAT Mean', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Fwd Header Len', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']
# [0.9999537617884362, 0.9999537617884362, 'SYN Flag Cnt', ['Fwd PSH Flags', 'URG Flag Cnt', 'protocol_HOPOPT', 'Bwd IAT Tot', 'Bwd IAT Std', 'Flow IAT Min', 'Fwd IAT Min', 'Bwd IAT Max', 'Active Std', 'Idle Min', 'Fwd IAT Mean', 'Flow IAT Mean', 'Active Min', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Bwd IAT Mean', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Fwd Header Len', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']]
# -------------------Checking for 63 Features-------------------
# Testing for importance of Fwd PSH Flags
# Testing for 64 Features
# 63: 0.9999466430592884 & 0.9999537617884362
# Testing for importance of URG Flag Cnt
# Testing for 64 Features
# 63: 0.999950202663937 & 0.9999537617884362
# Testing for importance of protocol_HOPOPT
# Testing for 64 Features
# 63: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Bwd IAT Tot
# Testing for 64 Features
# 63: 0.9999537617884362 & 0.9999537617884362
# 63 Features after removal: ['Fwd PSH Flags', 'URG Flag Cnt', 'protocol_HOPOPT', 'Bwd IAT Std', 'Flow IAT Min', 'Fwd IAT Min', 'Bwd IAT Max', 'Active Std', 'Idle Min', 'Fwd IAT Mean', 'Flow IAT Mean', 'Active Min', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Bwd IAT Mean', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Fwd Header Len', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']
# [0.9999537617884362, 0.9999537617884362, 'Bwd IAT Tot', ['Fwd PSH Flags', 'URG Flag Cnt', 'protocol_HOPOPT', 'Bwd IAT Std', 'Flow IAT Min', 'Fwd IAT Min', 'Bwd IAT Max', 'Active Std', 'Idle Min', 'Fwd IAT Mean', 'Flow IAT Mean', 'Active Min', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Bwd IAT Mean', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Fwd Header Len', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']]
# -------------------Checking for 62 Features-------------------
# Testing for importance of Fwd PSH Flags
# Testing for 63 Features
# 62: 0.9999466430592884 & 0.9999537617884362
# Testing for importance of URG Flag Cnt
# Testing for 63 Features
# 62: 0.999950202663937 & 0.9999537617884362
# Testing for importance of protocol_HOPOPT
# Testing for 63 Features
# 62: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Bwd IAT Std
# Testing for 63 Features
# 62: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Flow IAT Min
# Testing for 63 Features
# 62: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Fwd IAT Min
# Testing for 63 Features
# 62: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Bwd IAT Max
# Testing for 63 Features
# 62: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Active Std
# Testing for 63 Features
# 62: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Idle Min
# Testing for 63 Features
# 62: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Fwd IAT Mean
# Testing for 63 Features
# 62: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Flow IAT Mean
# Testing for 63 Features
# 62: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Active Min
# Testing for 63 Features
# 62: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Active Max
# Testing for 63 Features
# 62: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Flow IAT Max
# Testing for 63 Features
# 62: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Fwd IAT Max
# Testing for 63 Features
# 62: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Idle Std
# Testing for 63 Features
# 62: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Active Mean
# Testing for 63 Features
# 62: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Idle Mean
# Testing for 63 Features
# 62: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Flow IAT Std
# Testing for 63 Features
# 62: 0.9999466463881536 & 0.9999537617884362
# Testing for importance of Fwd IAT Std
# Testing for 63 Features
# 62: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Idle Max
# Testing for 63 Features
# 62: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Fwd Seg Size Min
# Testing for 63 Features
# 62: 0.9999181941202515 & 0.9999537617884362
# Testing for importance of protocol_TCP
# Testing for 63 Features
# 62: 0.999950202663937 & 0.9999537617884362
# Testing for importance of protocol_UDP
# Testing for 63 Features
# 62: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Flow Duration
# Testing for 63 Features
# 62: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Fwd IAT Tot
# Testing for 63 Features
# 62: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Bwd Pkt Len Max
# Testing for 63 Features
# 62: 0.9999430903763848 & 0.9999537617884362
# Testing for importance of TotLen Bwd Pkts
# Testing for 63 Features
# 62: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Subflow Bwd Byts
# Testing for 63 Features
# 62: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Bwd IAT Mean
# Testing for 63 Features
# 62: 0.9999537617884362 & 0.9999537617884362
# 62 Features after removal: ['Fwd PSH Flags', 'URG Flag Cnt', 'protocol_HOPOPT', 'Bwd IAT Std', 'Flow IAT Min', 'Fwd IAT Min', 'Bwd IAT Max', 'Active Std', 'Idle Min', 'Fwd IAT Mean', 'Flow IAT Mean', 'Active Min', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Fwd Header Len', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']
# [0.9999537617884362, 0.9999537617884362, 'Bwd IAT Mean', ['Fwd PSH Flags', 'URG Flag Cnt', 'protocol_HOPOPT', 'Bwd IAT Std', 'Flow IAT Min', 'Fwd IAT Min', 'Bwd IAT Max', 'Active Std', 'Idle Min', 'Fwd IAT Mean', 'Flow IAT Mean', 'Active Min', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Fwd Header Len', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']]
# -------------------Checking for 61 Features-------------------
# Testing for importance of Fwd PSH Flags
# Testing for 62 Features
# 61: 0.9999466430592884 & 0.9999537617884362
# Testing for importance of URG Flag Cnt
# Testing for 62 Features
# 61: 0.999950202663937 & 0.9999537617884362
# Testing for importance of protocol_HOPOPT
# Testing for 62 Features
# 61: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Bwd IAT Std
# Testing for 62 Features
# 61: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Flow IAT Min
# Testing for 62 Features
# 61: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Fwd IAT Min
# Testing for 62 Features
# 61: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Bwd IAT Max
# Testing for 62 Features
# 61: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Active Std
# Testing for 62 Features
# 61: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Idle Min
# Testing for 62 Features
# 61: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Fwd IAT Mean
# Testing for 62 Features
# 61: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Flow IAT Mean
# Testing for 62 Features
# 61: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Active Min
# Testing for 62 Features
# 61: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Active Max
# Testing for 62 Features
# 61: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Flow IAT Max
# Testing for 62 Features
# 61: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Fwd IAT Max
# Testing for 62 Features
# 61: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Idle Std
# Testing for 62 Features
# 61: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Active Mean
# Testing for 62 Features
# 61: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Idle Mean
# Testing for 62 Features
# 61: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Flow IAT Std
# Testing for 62 Features
# 61: 0.9999466463881536 & 0.9999537617884362
# Testing for importance of Fwd IAT Std
# Testing for 62 Features
# 61: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Idle Max
# Testing for 62 Features
# 61: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Fwd Seg Size Min
# Testing for 62 Features
# 61: 0.9999181941202515 & 0.9999537617884362
# Testing for importance of protocol_TCP
# Testing for 62 Features
# 61: 0.999950202663937 & 0.9999537617884362
# Testing for importance of protocol_UDP
# Testing for 62 Features
# 61: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Flow Duration
# Testing for 62 Features
# 61: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Fwd IAT Tot
# Testing for 62 Features
# 61: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Bwd Pkt Len Max
# Testing for 62 Features
# 61: 0.9999430903763848 & 0.9999537617884362
# Testing for importance of TotLen Bwd Pkts
# Testing for 62 Features
# 61: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Subflow Bwd Byts
# Testing for 62 Features
# 61: 0.999950202663937 & 0.9999537617884362
# Testing for importance of Subflow Fwd Byts
# Testing for 62 Features
# 61: 0.9999537561664772 & 0.9999537617884362
# Testing for importance of TotLen Fwd Pkts
# Testing for 62 Features
# 61: 0.9999537561664772 & 0.9999537617884362
# Testing for importance of Fwd Header Len
# Testing for 62 Features
# 61: 0.9999573123744191 & 0.9999537617884362
# 61 Features after removal: ['Fwd PSH Flags', 'URG Flag Cnt', 'protocol_HOPOPT', 'Bwd IAT Std', 'Flow IAT Min', 'Fwd IAT Min', 'Bwd IAT Max', 'Active Std', 'Idle Min', 'Fwd IAT Mean', 'Flow IAT Mean', 'Active Min', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']
# [0.9999573123744191, 0.9999573123744191, 'Fwd Header Len', ['Fwd PSH Flags', 'URG Flag Cnt', 'protocol_HOPOPT', 'Bwd IAT Std', 'Flow IAT Min', 'Fwd IAT Min', 'Bwd IAT Max', 'Active Std', 'Idle Min', 'Fwd IAT Mean', 'Flow IAT Mean', 'Active Min', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']]
# -------------------Checking for 60 Features-------------------
# Testing for importance of Fwd PSH Flags
# Testing for 61 Features
# 60: 0.9999537527697707 & 0.9999573123744191
# Testing for importance of URG Flag Cnt
# Testing for 61 Features
# 60: 0.9999573123744191 & 0.9999573123744191
# 60 Features after removal: ['Fwd PSH Flags', 'protocol_HOPOPT', 'Bwd IAT Std', 'Flow IAT Min', 'Fwd IAT Min', 'Bwd IAT Max', 'Active Std', 'Idle Min', 'Fwd IAT Mean', 'Flow IAT Mean', 'Active Min', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']
# [0.9999573123744191, 0.9999573123744191, 'URG Flag Cnt', ['Fwd PSH Flags', 'protocol_HOPOPT', 'Bwd IAT Std', 'Flow IAT Min', 'Fwd IAT Min', 'Bwd IAT Max', 'Active Std', 'Idle Min', 'Fwd IAT Mean', 'Flow IAT Mean', 'Active Min', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']]
# -------------------Checking for 59 Features-------------------
# Testing for importance of Fwd PSH Flags
# Testing for 60 Features
# 59: 0.9999537527697707 & 0.9999573123744191
# Testing for importance of protocol_HOPOPT
# Testing for 60 Features
# 59: 0.9999573123744191 & 0.9999573123744191
# 59 Features after removal: ['Fwd PSH Flags', 'Bwd IAT Std', 'Flow IAT Min', 'Fwd IAT Min', 'Bwd IAT Max', 'Active Std', 'Idle Min', 'Fwd IAT Mean', 'Flow IAT Mean', 'Active Min', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']
# [0.9999573123744191, 0.9999573123744191, 'protocol_HOPOPT', ['Fwd PSH Flags', 'Bwd IAT Std', 'Flow IAT Min', 'Fwd IAT Min', 'Bwd IAT Max', 'Active Std', 'Idle Min', 'Fwd IAT Mean', 'Flow IAT Mean', 'Active Min', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']]
# -------------------Checking for 58 Features-------------------
# Testing for importance of Fwd PSH Flags
# Testing for 59 Features
# 58: 0.9999537527697707 & 0.9999573123744191
# Testing for importance of Bwd IAT Std
# Testing for 59 Features
# 58: 0.9999573123744191 & 0.9999573123744191
# 58 Features after removal: ['Fwd PSH Flags', 'Flow IAT Min', 'Fwd IAT Min', 'Bwd IAT Max', 'Active Std', 'Idle Min', 'Fwd IAT Mean', 'Flow IAT Mean', 'Active Min', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']
# [0.9999573123744191, 0.9999573123744191, 'Bwd IAT Std', ['Fwd PSH Flags', 'Flow IAT Min', 'Fwd IAT Min', 'Bwd IAT Max', 'Active Std', 'Idle Min', 'Fwd IAT Mean', 'Flow IAT Mean', 'Active Min', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']]
# -------------------Checking for 57 Features-------------------
# Testing for importance of Fwd PSH Flags
# Testing for 58 Features
# 57: 0.9999537527697707 & 0.9999573123744191
# Testing for importance of Flow IAT Min
# Testing for 58 Features
# 57: 0.9999573123744191 & 0.9999573123744191
# 57 Features after removal: ['Fwd PSH Flags', 'Fwd IAT Min', 'Bwd IAT Max', 'Active Std', 'Idle Min', 'Fwd IAT Mean', 'Flow IAT Mean', 'Active Min', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']
# [0.9999573123744191, 0.9999573123744191, 'Flow IAT Min', ['Fwd PSH Flags', 'Fwd IAT Min', 'Bwd IAT Max', 'Active Std', 'Idle Min', 'Fwd IAT Mean', 'Flow IAT Mean', 'Active Min', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']]
# -------------------Checking for 56 Features-------------------
# Testing for importance of Fwd PSH Flags
# Testing for 57 Features
# 56: 0.9999537527697707 & 0.9999573123744191
# Testing for importance of Fwd IAT Min
# Testing for 57 Features
# 56: 0.9999573123744191 & 0.9999573123744191
# 56 Features after removal: ['Fwd PSH Flags', 'Bwd IAT Max', 'Active Std', 'Idle Min', 'Fwd IAT Mean', 'Flow IAT Mean', 'Active Min', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']
# [0.9999573123744191, 0.9999573123744191, 'Fwd IAT Min', ['Fwd PSH Flags', 'Bwd IAT Max', 'Active Std', 'Idle Min', 'Fwd IAT Mean', 'Flow IAT Mean', 'Active Min', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']]
# -------------------Checking for 55 Features-------------------
# Testing for importance of Fwd PSH Flags
# Testing for 56 Features
# 55: 0.9999537527697707 & 0.9999573123744191
# Testing for importance of Bwd IAT Max
# Testing for 56 Features
# 55: 0.9999573123744191 & 0.9999573123744191
# 55 Features after removal: ['Fwd PSH Flags', 'Active Std', 'Idle Min', 'Fwd IAT Mean', 'Flow IAT Mean', 'Active Min', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']
# [0.9999573123744191, 0.9999573123744191, 'Bwd IAT Max', ['Fwd PSH Flags', 'Active Std', 'Idle Min', 'Fwd IAT Mean', 'Flow IAT Mean', 'Active Min', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']]
# -------------------Checking for 54 Features-------------------
# Testing for importance of Fwd PSH Flags
# Testing for 55 Features
# 54: 0.9999537527697707 & 0.9999573123744191
# Testing for importance of Active Std
# Testing for 55 Features
# 54: 0.9999573123744191 & 0.9999573123744191
# 54 Features after removal: ['Fwd PSH Flags', 'Idle Min', 'Fwd IAT Mean', 'Flow IAT Mean', 'Active Min', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']
# [0.9999573123744191, 0.9999573123744191, 'Active Std', ['Fwd PSH Flags', 'Idle Min', 'Fwd IAT Mean', 'Flow IAT Mean', 'Active Min', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']]
# -------------------Checking for 53 Features-------------------
# Testing for importance of Fwd PSH Flags
# Testing for 54 Features
# 53: 0.9999537527697707 & 0.9999573123744191
# Testing for importance of Idle Min
# Testing for 54 Features
# 53: 0.9999573123744191 & 0.9999573123744191
# 53 Features after removal: ['Fwd PSH Flags', 'Fwd IAT Mean', 'Flow IAT Mean', 'Active Min', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']
# [0.9999573123744191, 0.9999573123744191, 'Idle Min', ['Fwd PSH Flags', 'Fwd IAT Mean', 'Flow IAT Mean', 'Active Min', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']]
# -------------------Checking for 52 Features-------------------
# Testing for importance of Fwd PSH Flags
# Testing for 53 Features
# 52: 0.9999537527697707 & 0.9999573123744191
# Testing for importance of Fwd IAT Mean
# Testing for 53 Features
# 52: 0.9999573123744191 & 0.9999573123744191
# 52 Features after removal: ['Fwd PSH Flags', 'Flow IAT Mean', 'Active Min', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']
# [0.9999573123744191, 0.9999573123744191, 'Fwd IAT Mean', ['Fwd PSH Flags', 'Flow IAT Mean', 'Active Min', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']]
# -------------------Checking for 51 Features-------------------
# Testing for importance of Fwd PSH Flags
# Testing for 52 Features
# 51: 0.9999537527697707 & 0.9999573123744191
# Testing for importance of Flow IAT Mean
# Testing for 52 Features
# 51: 0.9999573123744191 & 0.9999573123744191
# 51 Features after removal: ['Fwd PSH Flags', 'Active Min', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']
# [0.9999573123744191, 0.9999573123744191, 'Flow IAT Mean', ['Fwd PSH Flags', 'Active Min', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']]
# -------------------Checking for 50 Features-------------------
# Testing for importance of Fwd PSH Flags
# Testing for 51 Features
# 50: 0.9999537527697707 & 0.9999573123744191
# Testing for importance of Active Min
# Testing for 51 Features
# 50: 0.9999573123744191 & 0.9999573123744191
# 50 Features after removal: ['Fwd PSH Flags', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']
# [0.9999573123744191, 0.9999573123744191, 'Active Min', ['Fwd PSH Flags', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Act Data Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']]
# -------------------Checking for 49 Features-------------------
# Testing for importance of Fwd PSH Flags
# Testing for 50 Features
# 49: 0.9999501937138642 & 0.9999573123744191
# Testing for importance of Active Max
# Testing for 50 Features
# 49: 0.999953753318494 & 0.9999573123744191
# Testing for importance of Flow IAT Max
# Testing for 50 Features
# 49: 0.999953753318494 & 0.9999573123744191
# Testing for importance of Fwd IAT Max
# Testing for 50 Features
# 49: 0.999953753318494 & 0.9999573123744191
# Testing for importance of Idle Std
# Testing for 50 Features
# 49: 0.999953753318494 & 0.9999573123744191
# Testing for importance of Active Mean
# Testing for 50 Features
# 49: 0.999953753318494 & 0.9999573123744191
# Testing for importance of Idle Mean
# Testing for 50 Features
# 49: 0.999953753318494 & 0.9999573123744191
# Testing for importance of Flow IAT Std
# Testing for 50 Features
# 49: 0.9999501971105521 & 0.9999573123744191
# Testing for importance of Fwd IAT Std
# Testing for 50 Features
# 49: 0.999953753318494 & 0.9999573123744191
# Testing for importance of Idle Max
# Testing for 50 Features
# 49: 0.999953753318494 & 0.9999573123744191
# Testing for importance of Fwd Seg Size Min
# Testing for 50 Features
# 49: 0.999918185507751 & 0.9999573123744191
# Testing for importance of protocol_TCP
# Testing for 50 Features
# 49: 0.999953753318494 & 0.9999573123744191
# Testing for importance of protocol_UDP
# Testing for 50 Features
# 49: 0.999953753318494 & 0.9999573123744191
# Testing for importance of Flow Duration
# Testing for 50 Features
# 49: 0.999953753318494 & 0.9999573123744191
# Testing for importance of Fwd IAT Tot
# Testing for 50 Features
# 49: 0.999953753318494 & 0.9999573123744191
# Testing for importance of Bwd Pkt Len Max
# Testing for 50 Features
# 49: 0.9999466410994999 & 0.9999573123744191
# Testing for importance of TotLen Bwd Pkts
# Testing for 50 Features
# 49: 0.9999502000868578 & 0.9999573123744191
# Testing for importance of Subflow Bwd Byts
# Testing for 50 Features
# 49: 0.9999502000868578 & 0.9999573123744191
# Testing for importance of Subflow Fwd Byts
# Testing for 50 Features
# 49: 0.9999537562269655 & 0.9999573123744191
# Testing for importance of TotLen Fwd Pkts
# Testing for 50 Features
# 49: 0.9999537562269655 & 0.9999573123744191
# Testing for importance of Subflow Fwd Pkts
# Testing for 50 Features
# 49: 0.999953753318494 & 0.9999573123744191
# Testing for importance of Tot Fwd Pkts
# Testing for 50 Features
# 49: 0.999953753318494 & 0.9999573123744191
# Testing for importance of Fwd Act Data Pkts
# Testing for 50 Features
# 49: 0.9999573123744191 & 0.9999573123744191
# 49 Features after removal: ['Fwd PSH Flags', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']
# [0.9999573123744191, 0.9999573123744191, 'Fwd Act Data Pkts', ['Fwd PSH Flags', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Fwd Pkts/s', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']]
# -------------------Checking for 48 Features-------------------
# Testing for importance of Fwd PSH Flags
# Testing for 49 Features
# 48: 0.9999501937138642 & 0.9999573123744191
# Testing for importance of Active Max
# Testing for 49 Features
# 48: 0.999953753318494 & 0.9999573123744191
# Testing for importance of Flow IAT Max
# Testing for 49 Features
# 48: 0.999953753318494 & 0.9999573123744191
# Testing for importance of Fwd IAT Max
# Testing for 49 Features
# 48: 0.999953753318494 & 0.9999573123744191
# Testing for importance of Idle Std
# Testing for 49 Features
# 48: 0.999953753318494 & 0.9999573123744191
# Testing for importance of Active Mean
# Testing for 49 Features
# 48: 0.999953753318494 & 0.9999573123744191
# Testing for importance of Idle Mean
# Testing for 49 Features
# 48: 0.999953753318494 & 0.9999573123744191
# Testing for importance of Flow IAT Std
# Testing for 49 Features
# 48: 0.9999501971105521 & 0.9999573123744191
# Testing for importance of Fwd IAT Std
# Testing for 49 Features
# 48: 0.999953753318494 & 0.9999573123744191
# Testing for importance of Idle Max
# Testing for 49 Features
# 48: 0.999953753318494 & 0.9999573123744191
# Testing for importance of Fwd Seg Size Min
# Testing for 49 Features
# 48: 0.999918185507751 & 0.9999573123744191
# Testing for importance of protocol_TCP
# Testing for 49 Features
# 48: 0.999953753318494 & 0.9999573123744191
# Testing for importance of protocol_UDP
# Testing for 49 Features
# 48: 0.999953753318494 & 0.9999573123744191
# Testing for importance of Flow Duration
# Testing for 49 Features
# 48: 0.999953753318494 & 0.9999573123744191
# Testing for importance of Fwd IAT Tot
# Testing for 49 Features
# 48: 0.999953753318494 & 0.9999573123744191
# Testing for importance of Bwd Pkt Len Max
# Testing for 49 Features
# 48: 0.9999466410994999 & 0.9999573123744191
# Testing for importance of TotLen Bwd Pkts
# Testing for 49 Features
# 48: 0.9999502000868578 & 0.9999573123744191
# Testing for importance of Subflow Bwd Byts
# Testing for 49 Features
# 48: 0.9999502000868578 & 0.9999573123744191
# Testing for importance of Subflow Fwd Byts
# Testing for 49 Features
# 48: 0.9999537562269655 & 0.9999573123744191
# Testing for importance of TotLen Fwd Pkts
# Testing for 49 Features
# 48: 0.9999537562269655 & 0.9999573123744191
# Testing for importance of Subflow Fwd Pkts
# Testing for 49 Features
# 48: 0.999953753318494 & 0.9999573123744191
# Testing for importance of Tot Fwd Pkts
# Testing for 49 Features
# 48: 0.999953753318494 & 0.9999573123744191
# Testing for importance of Fwd Pkts/s
# Testing for 49 Features
# 48: 0.9999679875180106 & 0.9999573123744191
# 48 Features after removal: ['Fwd PSH Flags', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']
# [0.9999679875180106, 0.9999679875180106, 'Fwd Pkts/s', ['Fwd PSH Flags', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Bwd Header Len', 'Flow Pkts/s', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']]
# -------------------Checking for 47 Features-------------------
# Testing for importance of Fwd PSH Flags
# Testing for 48 Features
# 47: 0.9999608689946272 & 0.9999679875180106
# Testing for importance of Active Max
# Testing for 48 Features
# 47: 0.9999644284620552 & 0.9999679875180106
# Testing for importance of Flow IAT Max
# Testing for 48 Features
# 47: 0.9999644284620552 & 0.9999679875180106
# Testing for importance of Fwd IAT Max
# Testing for 48 Features
# 47: 0.9999644284620552 & 0.9999679875180106
# Testing for importance of Idle Std
# Testing for 48 Features
# 47: 0.9999644284620552 & 0.9999679875180106
# Testing for importance of Active Mean
# Testing for 48 Features
# 47: 0.9999644284620552 & 0.9999679875180106
# Testing for importance of Idle Mean
# Testing for 48 Features
# 47: 0.9999644284620552 & 0.9999679875180106
# Testing for importance of Flow IAT Std
# Testing for 48 Features
# 47: 0.999964431377903 & 0.9999679875180106
# Testing for importance of Fwd IAT Std
# Testing for 48 Features
# 47: 0.9999644284620552 & 0.9999679875180106
# Testing for importance of Idle Max
# Testing for 48 Features
# 47: 0.9999644284620552 & 0.9999679875180106
# Testing for importance of Fwd Seg Size Min
# Testing for 48 Features
# 47: 0.9999288614022004 & 0.9999679875180106
# Testing for importance of protocol_TCP
# Testing for 48 Features
# 47: 0.9999644284620552 & 0.9999679875180106
# Testing for importance of protocol_UDP
# Testing for 48 Features
# 47: 0.9999644284620552 & 0.9999679875180106
# Testing for importance of Flow Duration
# Testing for 48 Features
# 47: 0.9999644284620552 & 0.9999679875180106
# Testing for importance of Fwd IAT Tot
# Testing for 48 Features
# 47: 0.9999644284620552 & 0.9999679875180106
# Testing for importance of Bwd Pkt Len Max
# Testing for 48 Features
# 47: 0.9999573162430263 & 0.9999679875180106
# Testing for importance of TotLen Bwd Pkts
# Testing for 48 Features
# 47: 0.999960875230419 & 0.9999679875180106
# Testing for importance of Subflow Bwd Byts
# Testing for 48 Features
# 47: 0.999960875230419 & 0.9999679875180106
# Testing for importance of Subflow Fwd Byts
# Testing for 48 Features
# 47: 0.999960875230419 & 0.9999679875180106
# Testing for importance of TotLen Fwd Pkts
# Testing for 48 Features
# 47: 0.999960875230419 & 0.9999679875180106
# Testing for importance of Subflow Fwd Pkts
# Testing for 48 Features
# 47: 0.9999644284620552 & 0.9999679875180106
# Testing for importance of Tot Fwd Pkts
# Testing for 48 Features
# 47: 0.9999644284620552 & 0.9999679875180106
# Testing for importance of Bwd Header Len
# Testing for 48 Features
# 47: 0.999960875230419 & 0.9999679875180106
# Testing for importance of Flow Pkts/s
# Testing for 48 Features
# 47: 0.999971540952818 & 0.9999679875180106
# 47 Features after removal: ['Fwd PSH Flags', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Bwd Header Len', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']
# [0.999971540952818, 0.999971540952818, 'Flow Pkts/s', ['Fwd PSH Flags', 'Active Max', 'Flow IAT Max', 'Fwd IAT Max', 'Idle Std', 'Active Mean', 'Idle Mean', 'Flow IAT Std', 'Fwd IAT Std', 'Idle Max', 'Fwd Seg Size Min', 'protocol_TCP', 'protocol_UDP', 'Flow Duration', 'Fwd IAT Tot', 'Bwd Pkt Len Max', 'TotLen Bwd Pkts', 'Subflow Bwd Byts', 'Subflow Fwd Byts', 'TotLen Fwd Pkts', 'Subflow Fwd Pkts', 'Tot Fwd Pkts', 'Bwd Header Len', 'Bwd Pkt Len Std', 'Down/Up Ratio', 'Subflow Bwd Pkts', 'Tot Bwd Pkts', 'Bwd IAT Min', 'Bwd Pkts/s', 'Bwd Seg Size Avg', 'Bwd Pkt Len Mean', 'Flow Byts/s', 'ACK Flag Cnt', 'Init Fwd Win Byts', 'Pkt Size Avg', 'Pkt Len Mean', 'ECE Flag Cnt', 'RST Flag Cnt', 'Pkt Len Var', 'Pkt Len Std', 'Pkt Len Max', 'PSH Flag Cnt', 'Fwd Seg Size Avg', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Fwd Pkt Len Max', 'Init Bwd Win Byts']]
# -------------------Checking for 46 Features-------------------
# Testing for importance of Fwd PSH Flags
# Testing for 47 Features
# 46: 0.9999644224294346 & 0.999971540952818
# Testing for importance of Active Max
# Testing for 47 Features
# 46: 0.9999679818968625 & 0.999971540952818
# Testing for importance of Flow IAT Max
# Testing for 47 Features
# 46: 0.9999679818968625 & 0.999971540952818
# Testing for importance of Fwd IAT Max
# Testing for 47 Features
# 46: 0.9999679818968625 & 0.999971540952818
# Testing for importance of Idle Std
# Testing for 47 Features
# 46: 0.9999679818968625 & 0.999971540952818
# Testing for importance of Active Mean
# Testing for 47 Features
# 46: 0.9999679818968625 & 0.999971540952818
# Testing for importance of Idle Mean
# Testing for 47 Features
# 46: 0.9999679818968625 & 0.999971540952818
# Testing for importance of Flow IAT Std
# Testing for 47 Features
# 46: 0.9999679848127103 & 0.999971540952818
# Testing for importance of Fwd IAT Std
# Testing for 47 Features
# 46: 0.9999679818968625 & 0.999971540952818
# Testing for importance of Idle Max
# Testing for 47 Features
# 46: 0.9999679818968625 & 0.999971540952818
# Testing for importance of Fwd Seg Size Min
# Testing for 47 Features
# 46: 0.9999430876156762 & 0.999971540952818
# Testing for importance of protocol_TCP
# Testing for 47 Features
# 46: 0.9999679818968625 & 0.999971540952818
# Testing for importance of protocol_UDP
# Testing for 47 Features
# 46: 0.9999679818968625 & 0.999971540952818
# Testing for importance of Flow Duration
# Testing for 47 Features
# 46: 0.9999679818968625 & 0.999971540952818
# Testing for importance of Fwd IAT Tot
# Testing for 47 Features
# 46: 0.9999679818968625 & 0.999971540952818
# Testing for importance of Bwd Pkt Len Max
# Testing for 47 Features
# 46: 0.9999608696778268 & 0.999971540952818
# Testing for importance of TotLen Bwd Pkts
# Testing for 47 Features
# 46: 0.9999644286652194 & 0.999971540952818
# Testing for importance of Subflow Bwd Byts
# Testing for 47 Features
# 46: 0.9999644286652194 & 0.999971540952818
# Testing for importance of Subflow Fwd Byts
# Testing for 47 Features
# 46: 0.9999644286652194 & 0.999971540952818
# Testing for importance of TotLen Fwd Pkts
# Testing for 47 Features
# 46: 0.9999644286652194 & 0.999971540952818
# Testing for importance of Subflow Fwd Pkts
# Testing for 47 Features

# %%
scoresRF, final_featuresRF = modified_backward_wrapper(df, test, RandomForestClassifier(), ranked_features, MIN_NUM_FEATURES - random.choice(5,10), NUM_FOLDS, THRESHOLD, AGGRESSIVE)

# %%
scoresSVC, final_featuresSVC = modified_backward_wrapper(df, test, LinearSVC(dual=False), ranked_features, MIN_NUM_FEATURES - random.choice(5, 10), NUM_FOLDS, THRESHOLD, AGGRESSIVE)

# %%
final_scores = pd.DataFrame(scores).transpose()
final_scores.columns = ["A", "B", "C", "D"]
#final_scores.columns = ["Score for Iteration", "Overall Accuracy", "Feature Removed", "Score against Test Data"]
print(final_scores)

# %%
myModel
